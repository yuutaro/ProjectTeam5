# %% [markdown]
# # Week 9 練習と総合問題解答

# %%
# 以下のライブラリを使うので、あらかじめ読み込んでおいてください
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series,DataFrame
import os
import zipfile
import requests
import io

# 可視化ライブラリ
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# 小数第３位まで表示
# %precision 3
# Out:
# '%.3f'

# %% [markdown]
# #### <練習問題 6>
#
# 作成したDataFrame、pm25を使って、年ごとの平均値の推移データを作成してください。

# %%
import pandas_datareader.data as pdr

# データがあるurlの指定
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00381/PRSA_data_2010.1.1-2014.12.31.csv'

# データをurlから取得する
r = requests.get(url, stream=True).content
# データをDataFrameとして読み込む
Beijing_pm25=pd.read_csv(io.BytesIO(r))

#pm25のDataFrameを作成する
pm25 = pd.DataFrame(Beijing_pm25['pm2.5'].values,index = pd.to_datetime(Beijing_pm25[['year','month','day','hour']]),columns=['pm2.5'])

# %%
# 解答
pm25.resample('Y').mean().head()
# Out:
#                  pm2.5
# 2010-12-31  104.045730
# 2011-12-31   99.071340
# 2012-12-31   90.545871
# 2013-12-31  101.712376
# 2014-12-31   97.734557

# %% [markdown]
# #### <練習問題 7>
#
# <練習問題 6>で使用したpm25を使って、20日間の移動平均データを作成してください。ただしNaNは削除してください。なお、レコードとして存在しないデータであれば、特に補填する必要はありません。

# %%
import pandas_datareader.data as pdr

# データがあるurlの指定
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00381/PRSA_data_2010.1.1-2014.12.31.csv'

# データをurlから取得する
r = requests.get(url, stream=True).content
# データをDataFrameとして読み込む
Beijing_pm25=pd.read_csv(io.BytesIO(r))

#pm25のDataFrameを作成する
pm25 = pd.DataFrame(Beijing_pm25['pm2.5'].values,index = pd.to_datetime(Beijing_pm25[['year','month','day' ,"hour"]]),columns=['pm2.5'])

# %%
# 解答
pm25 = pm25.resample("D").mean()
pm25_rolling20 = pm25.rolling(20).mean().dropna()
pm25_rolling20.head()
# Out:
#                  pm2.5
# 2010-01-21  103.312500
# 2010-01-22   97.485417
# 2010-01-23   94.702574
# 2010-02-14   77.167482
# 2010-02-15   68.888315
