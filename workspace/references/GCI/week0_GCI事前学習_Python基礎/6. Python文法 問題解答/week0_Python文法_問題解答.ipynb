# %% [markdown]
# ## Python文法練習問題 解答集
# 関連解説動画：https://youtu.be/Z--qkNuCDUU

# %% [markdown]
# ## 練習問題

# %% [markdown]
# (1) 変数`x`に整数が格納されているとします。`x`が偶数ならば0、奇数ならば1を返すプログラムを作成してください。

# %%
# 入力例
x = 1

# %%
print(x%2) # 2で割った余り
# Out:
# 1

# %% [markdown]
# (2)身長height、体重weightからBMIを計算するプログラムを作成してください。

# %%
# 入力例
weight = 50 # kg
height = 165 # cm

bmi = # write me
print(bmi)

# %%
weight = 50 # kg
height = 165 # cm
bmi = weight / ((height / 100) ** 2) # 体重/ 身長の2乗
print(bmi)

# %% [markdown]
# (3) 要素がすべて整数値であって、長さが1以上のリストが変数xに格納されているとします。xの要素の中で最も大きい要素を返すプログラムを作成してください。ただし、max関数などは使用せず、ループ（for文での繰り返し）で実現してください。

# %%
# 入力例
x = [1, 5, 4, 3]

# %%
# 最大値を変数maxに格納する
max = x[0] # maxの初期値は配列の先頭にする
for i in x:
    if max < i:
        max = i # maxをiに入れ替える
print(max)
# Out:
# 5

# %% [markdown]
# (4) 長さが1以上の文字列を引数`x`とし、`x`の最後の1文字を返す関数`f`を定義してください。

# %%
# 入力例
x = 'python'

# %%
def f(x):
    length = len(x) # 文字列の長さ
    return x[length - 1] # 0から始まるので、lengthより１つ小さいインデックスを指定
f(x)
# Out:
# 'x'

# %%
# 別解
def f(x):
    return x[-1]
f(x)
# Out:
# 'x'

# %% [markdown]
# (5) 辞書を引数`x`とし、`x`に格納されているキーの数を返す関数`f`を定義してください。

# %%
# 入力例
x = {"a": 1, "b": 2, "c": 3, 'd':4, 'e':5}

# %%
def f(x):
    num_key = x.keys() # keys()は、辞書のキーを取得する関数
    return len(num_key) # num_keyの長さがキーの数となる
f(x)
# Out:
# 5

# %% [markdown]
# (6) リストを引数`x`とし、`x`の要素を逆順に並べたリストを返す関数`f`を定義してください。ただし、`reversed`関数などは使用せず、ループやリストのスライスで実現してください。

# %%
# 入力例
x = [3, 9, 7, 1, 0]

# %%
def f(x):
    reverse = [] # 結果を入れる変数(空箱)を用意する
    length = len(x) # 繰り返し回数
    for i in range(1,length + 1):
        reverse.append(x[-i]) # 後ろに追加していく
    return reverse

f(x)
# Out:
# [0, 1, 7, 9, 3]
